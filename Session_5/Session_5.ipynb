# %%
print("Hello World")
# Out:
# Hello World

# %%
print(2+2)
# Out:
# 4

# %%
a=5
b=8
print(a*b)
# Out:
# 40

# %%
i=8
if i<9:print(i)
# Out:
# 8

# %%
age=10

# %% [markdown]
# ## Sample py codes are written above
# You can access it [here](https://www.kaggle.com/)
#
# ![Image](https://www.magnific.com/free-photos-vectors/tiger-svg)
